# %%
from dao2 import ReclamoDAO
print("listo")
# Out:
# /opt/oracle/instantclient_19_22
# entering parameters config
# finished config for parameters
# entering parameters config
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3112, in Engine._wrap_pool_connect(self, fn, connection)
#    3111 try:
# -> 3112     return fn()
#    3113 except dialect.dbapi.Error as e:
#
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/pool/base.py:301, in Pool.connect(self)
#     294 """Return a DBAPI connection from the pool.
#     295
#     296 The connection is instrumented such that when its
#    (...)
#     299
#     300 """
# --> 301 return _ConnectionFairy._checkout(self)
#
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/pool/base.py:748, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     747 if not fairy:
# ...

# %%
data = ReclamoDAO()
gestores = data.get_managers()

# %%
gestores
# Out:
# [(1.0, 'Peter', 'Parker', 'PPARKER@gmail.com', '34535479', '23010166', '1234'),
#  (2.0, 'Bruce', 'Banner', 'BBANNER@gmail.com', '345426664', '26087566', '2345'),
#  (3.0, 'Matt', 'Murdock', 'MMURDOCK@gmail.com', '344566664', '27943166', '3456'),
#  (4.0, 'Stephen', 'Strange', 'SSTRANGE@gmail.com', '345373164', '20791249', '4567')]

# %%
gestor_id = data.get_managers(ges_id=1)
gestor_id
# Out:
# [(1.0, 'Peter', 'Parker', 'PPARKER@gmail.com', '34535479', '23010166', '1234')]

# %%
gestor_DNI = data.get_managers(ges_DNI='26087566')
gestor_DNI
# Out:
# [(2.0, 'Bruce', 'Banner', 'BBANNER@gmail.com', '345426664', '26087566', '2345')]

# %%
gestor_name = data.get_managers(ges_nombre='Peter')
gestor_name
# Out:
# [(1.0, 'Peter', 'Parker', 'PPARKER@gmail.com', '34535479', '23010166', '1234')]

# %%
gestor_apellido = data.get_managers(ges_apellido='Murdock')
gestor_apellido
# Out:
# [(3.0, 'Matt', 'Murdock', 'MMURDOCK@gmail.com', '344566664', '27943166', '3456')]
